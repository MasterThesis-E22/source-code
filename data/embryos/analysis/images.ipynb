# %% [markdown]
# # Imports

# %%
import os.path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image as Image

def load_embryos_image(path, focal, frame, width, height):
        file_data = np.load(path)
        images = file_data['images']

        focal = focal
        frame = frame
        img_raw = images[frame, :, :, focal]
        img = Image.fromarray(img_raw)
        img = resize_image(img, width, height)
        return img

def resize_image(image, width, height):
        newSize = (width, height)
        img = image.resize(newSize)
        return img

def normalize_image(image):
        img_raw = np.asarray(image)
        img_raw = img_raw.astype('float32') / 255
        return img_raw

# %% [markdown]
# # Configs

# %%
data_root = '/mnt/data/mlr_ahj_datasets/vitrolife/dataset/'
metadata_file_path = os.path.join(data_root, "metadata.csv")

# %% [markdown]
# # Image Analysis

# %% [markdown]
# ## Focal / Time

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 500, 500)
display(image)
image = resize_image(image, 250, 250)
display(image)
image = resize_image(image, 125, 125)
display(image)

# %% [markdown]
# ## Frames

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 250, 250)
display(image)
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 1, 250, 250)
display(image)
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 2, 250, 250)
display(image)
# Out:
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>

# %% [markdown]
# ## Spectrogram

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 125, 125)
image = np.asarray(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,255])
plt.show()

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 250, 250)
image = np.asarray(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,255])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 4
#       1 image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 250, 250)
#       2 image = np.asarray(image)
# ----> 4 b, bins, patches = plt.hist(image, 255)
#       5 plt.xlim([0,255])
#       6 plt.show()
#
# File ~/data/venv/lib/python3.8/site-packages/matplotlib/pyplot.py:2561, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2555 @_copy_docstring_and_deprecators(Axes.hist)
#    2556 def hist(
#    2557         x, bins=None, range=None, density=False, weights=None,
#    2558         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2559         orientation='vertical', rwidth=None, log=False, color=None,
#    2560         label=None, stacked=False, *, data=None, **kwargs):
# ...

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 500, 500)
image = np.asarray(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,255])
plt.show()

# %% [markdown]
# ## Normalization

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 125, 125)
image = normalize_image(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,1])
plt.show()

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 500, 500)
display(image)
image = resize_image(image, 250, 250)
display(image)
image = resize_image(image, 125, 125)
display(image)
# Out:
# <PIL.Image.Image image mode=L size=500x500>
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=125x125>

# %% [markdown]
# ## Focals

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 250, 250)
display(image)
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 1, 0, 250, 250)
display(image)
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 2, 0, 250, 250)
display(image)
# Out:
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>

# %% [markdown]
# ## Frames

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 250, 250)
display(image)
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 1, 250, 250)
display(image)
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 2, 250, 250)
display(image)
# Out:
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>
# <PIL.Image.Image image mode=L size=250x250>

# %% [markdown]
# ## Spectrogram

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 125, 125)
image = np.asarray(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,255])
plt.show()

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 250, 250)
image = np.asarray(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,255])
plt.show()

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 500, 500)
image = np.asarray(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,255])
plt.show()

# %% [markdown]
# ## Normalization

# %%
image = load_embryos_image(os.path.join(data_root, "00000.npz"), 0, 0, 125, 125)
image = normalize_image(image)

b, bins, patches = plt.hist(image, 255)
plt.xlim([0,1])
plt.show()
